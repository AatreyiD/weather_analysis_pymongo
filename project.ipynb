# %% [markdown]
# imports

# %%
from pymongo import MongoClient as mc

# %%
client = mc('mongodb://localhost:27017/')
db = client['project']
weather = db['weather']

# %% [markdown]
# number of records for each country

# %%
pipeline = [
  {'$group': {
      '_id': "$city.country",
      'recordCount': { '$sum': 1 }}},
  {'$sort': { 'recordCount': -1 }}
]

for doc in weather.aggregate(pipeline):
    print(doc)
# Out:
# {'_id': 'DE', 'recordCount': 28786}
# {'_id': 'US', 'recordCount': 19972}
# {'_id': 'FR', 'recordCount': 19965}
# {'_id': 'ES', 'recordCount': 15439}
# {'_id': 'IT', 'recordCount': 9878}
# {'_id': 'RU', 'recordCount': 8768}
# {'_id': 'CN', 'recordCount': 8715}
# {'_id': 'ID', 'recordCount': 6590}
# {'_id': 'AU', 'recordCount': 5593}
# {'_id': 'PH', 'recordCount': 4962}
# {'_id': 'GB', 'recordCount': 4882}
# {'_id': 'CH', 'recordCount': 4145}
# {'_id': 'PL', 'recordCount': 4100}
# {'_id': 'AT', 'recordCount': 3682}
# {'_id': 'IN', 'recordCount': 3634}
# {'_id': 'BR', 'recordCount': 3621}
# {'_id': 'CA', 'recordCount': 3302}
# {'_id': 'PT', 'recordCount': 3231}
# {'_id': 'RO', 'recordCount': 2872}
# {'_id': 'MX', 'recordCount': 2426}
# {'_id': 'AR', 'recordCount': 1743}
# {'_id': 'UA', 'recordCount': 1679}
# {'_id': 'CZ', 'recordCount': 1496}
# {'_id': 'BE', 'recordCount': 1452}
# {'_id': 'JP', 'recordCount': 1402}
# {'_id': 'BG', 'recordCount': 1370}
# {'_id': 'TR', 'recordCount': 1327}
# {'_id': 'GR', 'recordCount': 1323}
# {'_id': 'IE', 'recordCount': 1315}
# {'_id': 'TH', 'recordCount': 1234}
# {'_id': 'CO', 'recordCount': 1133}
# {'_id': 'HU', 'recordCount': 1109}
# {'_id': 'NL', 'recordCount': 1101}
# {'_id': 'SE', 'recordCount': 1053}
# {'_id': 'FI', 'recordCount': 903}
# {'_id': 'NO', 'recordCount': 776}
# {'_id': 'VE', 'recordCount': 732}
# {'_id': 'DK', 'recordCount': 576}
# {'_id': 'ZA', 'recordCount': 555}
# {'_id': 'PK', 'recordCount': 548}
# {'_id': 'BY', 'recordCount': 543}
# {'_id': 'RS', 'recordCount': 537}
# {'_id': 'KZ', 'recordCount': 530}
# {'_id': 'NG', 'recordCount': 521}
# {'_id': 'LU', 'recordCount': 520}
# {'_id': 'HR', 'recordCount': 508}
# {'_id': 'HN', 'recordCount': 462}
# {'_id': 'NZ', 'recordCount': 441}
# {'_id': 'AF', 'recordCount': 433}
# {'_id': 'DZ', 'recordCount': 419}
# {'_id': 'PE', 'recordCount': 418}
# {'_id': 'MA', 'recordCount': 395}
# {'_id': 'PR', 'recordCount': 390}
# {'_id': 'GT', 'recordCount': 385}
# {'_id': 'CL', 'recordCount': 369}
# {'_id': 'MN', 'recordCount': 358}
# {'_id': 'YE', 'recordCount': 354}
# {'_id': 'SI', 'recordCount': 351}
# {'_id': 'AM', 'recordCount': 332}
# {'_id': 'TZ', 'recordCount': 330}
# {'_id': 'PS', 'recordCount': 326}
# {'_id': 'IR', 'recordCount': 325}
# {'_id': 'EE', 'recordCount': 314}
# {'_id': 'DO', 'recordCount': 301}
# {'_id': 'NP', 'recordCount': 263}
# {'_id': 'MK', 'recordCount': 255}
# {'_id': 'BA', 'recordCount': 253}
# {'_id': 'BO', 'recordCount': 246}
# {'_id': 'PA', 'recordCount': 244}
# {'_id': 'KR', 'recordCount': 242}
# {'_id': 'SY', 'recordCount': 220}
# {'_id': 'MY', 'recordCount': 220}
# {'_id': 'IL', 'recordCount': 214}
# {'_id': 'AZ', 'recordCount': 204}
# {'_id': 'LV', 'recordCount': 197}
# {'_id': 'UZ', 'recordCount': 197}
# {'_id': 'EG', 'recordCount': 192}
# {'_id': 'EC', 'recordCount': 191}
# {'_id': 'MD', 'recordCount': 187}
# {'_id': 'UG', 'recordCount': 187}
# {'_id': 'TN', 'recordCount': 187}
# {'_id': 'SK', 'recordCount': 178}
# {'_id': 'CR', 'recordCount': 173}
# {'_id': 'PY', 'recordCount': 173}
# {'_id': 'CU', 'recordCount': 171}
# {'_id': 'VN', 'recordCount': 168}
# {'_id': 'CM', 'recordCount': 167}
# {'_id': 'UY', 'recordCount': 167}
# {'_id': 'IQ', 'recordCount': 162}
# {'_id': 'NI', 'recordCount': 157}
# {'_id': 'SV', 'recordCount': 154}
# {'_id': 'GE', 'recordCount': 149}
# {'_id': 'LT', 'recordCount': 142}
# {'_id': 'SA', 'recordCount': 140}
# {'_id': 'ET', 'recordCount': 138}
# {'_id': 'JM', 'recordCount': 138}
# {'_id': 'MU', 'recordCount': 133}
# {'_id': 'KE', 'recordCount': 131}
# {'_id': 'BD', 'recordCount': 131}
# {'_id': 'HT', 'recordCount': 127}
# {'_id': 'CD', 'recordCount': 125}
# {'_id': 'CI', 'recordCount': 120}
# {'_id': 'BF', 'recordCount': 113}
# {'_id': 'FM', 'recordCount': 111}
# {'_id': 'BW', 'recordCount': 109}
# {'_id': 'SD', 'recordCount': 106}
# {'_id': 'MG', 'recordCount': 106}
# {'_id': 'ZM', 'recordCount': 103}
# {'_id': 'SN', 'recordCount': 102}
# {'_id': 'MM', 'recordCount': 99}
# {'_id': 'GH', 'recordCount': 98}
# {'_id': 'TT', 'recordCount': 97}
# {'_id': 'LK', 'recordCount': 95}
# {'_id': 'JO', 'recordCount': 93}
# {'_id': 'KP', 'recordCount': 93}
# {'_id': 'TW', 'recordCount': 91}
# {'_id': 'CY', 'recordCount': 91}
# {'_id': 'TJ', 'recordCount': 90}
# {'_id': 'ZW', 'recordCount': 89}
# {'_id': 'KM', 'recordCount': 88}
# {'_id': 'AL', 'recordCount': 86}
# {'_id': 'SL', 'recordCount': 85}
# {'_id': 'LY', 'recordCount': 80}
# {'_id': 'GM', 'recordCount': 79}
# {'_id': 'SO', 'recordCount': 78}
# {'_id': 'KG', 'recordCount': 76}
# {'_id': 'XK', 'recordCount': 75}
# {'_id': 'PG', 'recordCount': 73}
# {'_id': 'TD', 'recordCount': 73}
# {'_id': 'GN', 'recordCount': 73}
# {'_id': 'LA', 'recordCount': 71}
# {'_id': 'MQ', 'recordCount': 71}
# {'_id': 'CF', 'recordCount': 69}
# {'_id': 'MW', 'recordCount': 69}
# {'_id': 'RE', 'recordCount': 69}
# {'_id': 'AO', 'recordCount': 69}
# {'_id': 'ML', 'recordCount': 68}
# {'_id': 'NA', 'recordCount': 66}
# {'_id': 'NC', 'recordCount': 62}
# {'_id': 'MT', 'recordCount': 60}
# {'_id': 'NE', 'recordCount': 56}
# {'_id': 'KH', 'recordCount': 56}
# {'_id': 'OM', 'recordCount': 54}
# {'_id': 'MZ', 'recordCount': 54}
# {'_id': 'GP', 'recordCount': 53}
# {'_id': 'BJ', 'recordCount': 51}
# {'_id': 'ME', 'recordCount': 51}
# {'_id': 'IS', 'recordCount': 51}
# {'_id': 'BB', 'recordCount': 49}
# {'_id': 'GU', 'recordCount': 49}
# {'_id': 'CV', 'recordCount': 48}
# {'_id': 'GA', 'recordCount': 46}
# {'_id': 'BT', 'recordCount': 45}
# {'_id': 'LB', 'recordCount': 44}
# {'_id': 'BS', 'recordCount': 44}
# {'_id': 'SS', 'recordCount': 43}
# {'_id': 'TM', 'recordCount': 40}
# {'_id': 'CG', 'recordCount': 40}
# {'_id': 'PF', 'recordCount': 39}
# {'_id': 'GF', 'recordCount': 36}
# {'_id': 'BI', 'recordCount': 36}
# {'_id': 'AX', 'recordCount': 35}
# {'_id': 'GL', 'recordCount': 35}
# {'_id': 'LR', 'recordCount': 34}
# {'_id': 'AE', 'recordCount': 33}
# {'_id': 'TG', 'recordCount': 33}
# {'_id': 'KW', 'recordCount': 33}
# {'_id': 'MH', 'recordCount': 31}
# {'_id': 'MR', 'recordCount': 31}
# {'_id': 'GQ', 'recordCount': 31}
# {'_id': 'GY', 'recordCount': 30}
# {'_id': 'FO', 'recordCount': 30}
# {'_id': 'DM', 'recordCount': 30}
# {'_id': 'SZ', 'recordCount': 29}
# {'_id': 'RW', 'recordCount': 29}
# {'_id': 'QA', 'recordCount': 28}
# {'_id': 'SR', 'recordCount': 27}
# {'_id': 'YT', 'recordCount': 27}
# {'_id': 'BZ', 'recordCount': 26}
# {'_id': 'KI', 'recordCount': 25}
# {'_id': 'VC', 'recordCount': 23}
# {'_id': 'IM', 'recordCount': 23}
# {'_id': 'KN', 'recordCount': 23}
# {'_id': 'ER', 'recordCount': 23}
# {'_id': 'WS', 'recordCount': 22}
# {'_id': 'LS', 'recordCount': 21}
# {'_id': 'GW', 'recordCount': 21}
# {'_id': 'GG', 'recordCount': 20}
# {'_id': 'AS', 'recordCount': 20}
# {'_id': 'GD', 'recordCount': 19}
# {'_id': 'LI', 'recordCount': 19}
# {'_id': 'DJ', 'recordCount': 19}
# {'_id': 'PW', 'recordCount': 19}
# {'_id': 'VU', 'recordCount': 18}
# {'_id': 'BH', 'recordCount': 18}
# {'_id': 'AD', 'recordCount': 18}
# {'_id': 'MV', 'recordCount': 18}
# {'_id': 'FJ', 'recordCount': 17}
# {'_id': 'LC', 'recordCount': 17}
# {'_id': 'HK', 'recordCount': 16}
# {'_id': 'AG', 'recordCount': 16}
# {'_id': 'SG', 'recordCount': 14}
# {'_id': 'BQ', 'recordCount': 14}
# {'_id': 'SB', 'recordCount': 13}
# {'_id': 'SM', 'recordCount': 12}
# {'_id': 'MP', 'recordCount': 12}
# {'_id': 'JE', 'recordCount': 12}
# {'_id': 'AW', 'recordCount': 11}
# {'_id': 'KY', 'recordCount': 11}
# {'_id': 'BN', 'recordCount': 10}
# {'_id': 'TO', 'recordCount': 10}
# {'_id': 'MS', 'recordCount': 8}
# {'_id': '', 'recordCount': 8}
# {'_id': 'MC', 'recordCount': 8}
# {'_id': 'TL', 'recordCount': 8}
# {'_id': 'ST', 'recordCount': 8}
# {'_id': 'CW', 'recordCount': 8}
# {'_id': 'VI', 'recordCount': 8}
# {'_id': 'AI', 'recordCount': 7}
# {'_id': 'SH', 'recordCount': 7}
# {'_id': 'EH', 'recordCount': 6}
# {'_id': 'TC', 'recordCount': 6}
# {'_id': 'SC', 'recordCount': 6}
# {'_id': 'WF', 'recordCount': 5}
# {'_id': 'TV', 'recordCount': 5}
# {'_id': 'BM', 'recordCount': 5}
# {'_id': 'SX', 'recordCount': 5}
# {'_id': 'SJ', 'recordCount': 5}
# {'_id': 'PM', 'recordCount': 4}
# {'_id': 'NR', 'recordCount': 4}
# {'_id': 'FK', 'recordCount': 4}
# {'_id': 'CK', 'recordCount': 4}
# {'_id': 'GI', 'recordCount': 4}
# {'_id': 'MF', 'recordCount': 3}
# {'_id': 'NF', 'recordCount': 3}
# {'_id': 'NU', 'recordCount': 3}
# {'_id': 'MO', 'recordCount': 3}
# {'_id': 'TF', 'recordCount': 3}
# {'_id': 'CX', 'recordCount': 3}
# {'_id': 'BL', 'recordCount': 3}
# {'_id': 'GS', 'recordCount': 2}
# {'_id': 'VA', 'recordCount': 2}
# {'_id': 'TK', 'recordCount': 2}
# {'_id': 'PN', 'recordCount': 2}
# {'_id': 'CC', 'recordCount': 2}
# {'_id': 'VG', 'recordCount': 2}
# {'_id': 'AQ', 'recordCount': 1}

# %% [markdown]
# country centroids & number of cities

# %%
pipeline = [
    # First group by city to get unique city coordinates
    {
        "$group": {
            "_id": {
                "country": "$city.country",
                "city": "$city.name"  # Assuming there's a city name field
            },
            "lat": {"$first": "$city.coord.lat"},  # Get one lat/lon per city
            "lon": {"$first": "$city.coord.lon"}
        }
    },
    # Then group by country to calculate averages
    {
        "$group": {
            "_id": "$_id.country",
            "avg_lat": {"$avg": "$lat"},
            "avg_lon": {"$avg": "$lon"},
            "cities": {"$sum": 1}  # Count of unique cities
        }
    },
    {"$sort": {"cities": -1}}
]

countries = {}

for doc in weather.aggregate(pipeline):
    countries[doc["_id"]] = {
        "centroid": (doc["avg_lat"], doc["avg_lon"]),
        "cities": doc["cities"]
	}

# %%
countries
# Out:
# {'DE': {'centroid': (50.958576323608334, 10.156532928721276), 'cities': 20497},
#  'US': {'centroid': (38.1189975430701, -91.66484866872933), 'cities': 14221},
#  'NU': {'centroid': (-19.025394000000002, -169.90067066666666), 'cities': 3},
#  'BL': {'centroid': (17.898726333333332, -62.844369), 'cities': 3},
#  'CC': {'centroid': (-12.160505, 96.847916), 'cities': 2},
#  'VG': {'centroid': (18.458334999999998, -64.5583345), 'cities': 2},
#  'VA': {'centroid': (41.9023035, 12.45331), 'cities': 2},
#  'TK': {'centroid': (-8.963640000000002, -171.88133249999998), 'cities': 2},
#  'GS': {'centroid': (-55.1405545, -34.754600499999995), 'cities': 2},
#  'PN': {'centroid': (-25.066319, -130.1007385), 'cities': 2},
#  'AQ': {'centroid': (-77.65535, 168.222656), 'cities': 1}}

# %%
import folium
from folium.plugins import MarkerCluster

# %%
m = folium.Map(location=[35.2866, 3.3774], zoom_start=2)

for country, data in countries.items():
    lat, lon = data["centroid"]
    
    # Create popup with country info
    popup_text = f"""
    <b>Country:</b> {country}<br>
    <b>Centroid:</b> {lat:.4f}, {lon:.4f}<br>
    <b>Cities:</b> {data['cities']}
    """
	# Add marker to map
    folium.Marker(
        location=[lat, lon],
        popup=folium.Popup(popup_text, max_width=250),
        icon=folium.Icon(color='blue', icon='globe', prefix='fa')
    ).add_to(m)

# %%
m.save('citycounts.html')

# %% [markdown]
# temperature cluster

# %%
from sklearn.cluster import KMeans
import numpy as np
from branca.colormap import linear

# %%
# 1. Fetch weather data with coordinates
pipeline = [
    {
        "$group": {
            "_id": {
                "city": "$city.name",
                "country": "$city.country"
            },
            "lat": {"$first": "$city.coord.lat"},
            "lon": {"$first": "$city.coord.lon"},
            "temp": {"$avg": "$main.temp"},
            "humidity": {"$avg": "$main.humidity"},
            "pressure": {"$avg": "$main.pressure"}
        }
    },
    {
        "$project": {
            "_id": 0,
            "city": "$_id.city",
            "country": "$_id.country",
            "lat": 1,
            "lon": 1,
            "temp": 1,
            "humidity": 1,
            "pressure": 1
        }
    }
]

data = list(weather.aggregate(pipeline))

# %%
# 2. Prepare data for clustering
features = np.array([
    [d['temp']] 
    for d in data
])

# %%
# 3. Perform K-Means clustering (let's use 5 clusters)
n_clusters = 10
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
clusters = kmeans.fit_predict(features)

# Add cluster labels back to our data
for i, d in enumerate(data):
    d['cluster'] = int(clusters[i])

# %%
# 4. Create a colored map
m = folium.Map(zoom_start=3)

# Create a color map for clusters
colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 
          'darkblue', 'darkgreen', 'cadetblue', 'darkpurple']
colormap = linear.Set3_12.scale(0, n_clusters-1)

# Add each city to the map with cluster color
for city in data:
    folium.CircleMarker(
        location=[city['lat'], city['lon']],
        radius=5,
        popup=f"""
        <b>{city['city']}, {city['country']}</b><br>
        Cluster: {city['cluster']}<br>
        Temp: {city['temp']:.1f}K<br>
        Humidity: {city['humidity']}%<br>
        Pressure: {city['pressure']} hPa
        """,
        color=colors[city['cluster'] % len(colors)],
        fill=True,
        fill_color=colors[city['cluster'] % len(colors)]
    ).add_to(m)

# Add cluster legend
colormap.caption = 'Weather Condition Clusters'
m.add_child(colormap)

# Save and display
m.save('temp_clusters.html')
# display(m)  # For Jupyter notebook, otherwise open the HTML file

# %%
client.close()
